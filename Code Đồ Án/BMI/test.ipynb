# %%
pip install matplotlib seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.8 MB 932.9 kB/s eta 0:00:08
#    ---- ----------------------------------- 0.8/7.8 MB 958.5 kB/s eta 0:00:08
#    ---- ----------------------------------- 0.8/7.8 MB 958.5 kB/s eta 0:00:08
#    ----- ---------------------------------- 1.0/7.8 MB 968.5 kB/s eta 0:00:08
#    ----- ---------------------------------- 1.0/7.8 MB 968.5 kB/s eta 0:00:08
#    ------ --------------------------------- 1.3/7.8 MB 762.6 kB/s eta 0:00:09
#    ------ --------------------------------- 1.3/7.8 MB 762.6 kB/s eta 0:00:09
#    ------ --------------------------------- 1.3/7.8 MB 762.6 kB/s eta 0:00:09
#    -------- ------------------------------- 1.6/7.8 MB 665.7 kB/s eta 0:00:10
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
test = pd.read_csv("D:/Thu thập & tiền xử lý dữ liệu/Đề Classroom/Titanic/test.csv")
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# # Tóm tắt thuộc tính bị thiếu

# %%
missing_data = test.isnull().sum()

# %%
missing_data_summary = missing_data[missing_data > 0].reset_index()

# %%
missing_data_summary.columns = ['Attribute', 'Missing Values']

# %%
missing_percentage = (missing_data / len(test)) *100 
missing_info = pd.DataFrame({
    'Column Name': missing_data.index,
    'Missing Count': missing_data.values,
    'Missing Percentage': missing_percentage.values
})

# %%
missing_info
# Out:
#     Column Name  Missing Count  Missing Percentage
# 0   PassengerId              0            0.000000
# 1        Pclass              0            0.000000
# 2          Name              0            0.000000
# 3           Sex              0            0.000000
# 4           Age             86           20.574163
# 5         SibSp              0            0.000000
# 6         Parch              0            0.000000
# 7        Ticket              0            0.000000
# 8          Fare              1            0.239234
# 9         Cabin            327           78.229665
# 10     Embarked              0            0.000000

# %% [markdown]
# # Biểu diễn
